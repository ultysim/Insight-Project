# %% [markdown]
# # Mixture Model Pong in action

# %% [markdown]
# This example will only train the expert on one batch of games, and run an experiment for a single game.
# In practice training should be much longer, on the order of 100 games, and testing should be at least 30.

# %%
import MixtureModelPong as mmp

# %% [markdown]
# ## Train a new expert or skip and use the trained model

# %%
mmp.train_expert.Train_Expert()
# Out:
# Loading model weights.
# Iteration 0, Episode 0 (20542 timesteps) - last_action: 1, last_action_prob: 0.64, reward_sum: 14.00, running_avg: 14.00
# Iteration 0, Episode 1 (11916 timesteps) - last_action: 2, last_action_prob: 0.99, reward_sum: 17.00, running_avg: 14.03
# Iteration 0, Episode 2 (23880 timesteps) - last_action: 0, last_action_prob: 0.24, reward_sum: 12.00, running_avg: 14.01
# Iteration 0, Episode 3 (20407 timesteps) - last_action: 2, last_action_prob: 0.99, reward_sum: 16.00, running_avg: 14.03
# Iteration 0, Episode 4 (19180 timesteps) - last_action: 1, last_action_prob: 0.97, reward_sum: 14.00, running_avg: 14.03
# Iteration 0, Episode 5 (17676 timesteps) - last_action: 1, last_action_prob: 0.36, reward_sum: 14.00, running_avg: 14.03
# Iteration 0, Episode 6 (18280 timesteps) - last_action: 1, last_action_prob: 0.97, reward_sum: 12.00, running_avg: 14.01
# ...

# %% [markdown]
# ## Run a mixture model experiment

# %%
mmp.mixturemodel.Run_MMP(mixture_weight=0.1, handicap=0)
# Out:
# Directory  data/02-06-13-31_0.1  Created
# Episode 0 (17846 timesteps) - Reward: 2.00
# Train batch 0/10
# Train batch 1/10
# Train batch 2/10
# Train batch 3/10
# Train batch 4/10
# Train batch 5/10
# Train batch 6/10
# Train batch 7/10
# Train batch 8/10
# Train batch 9/10
# 0.1751456745853877% correct guesses
# 0.9087214648723603 Cross Entropy Loss

# %% [markdown]
# ## The metrics after a full experiment

# %% [markdown]
# In the example we ran only one game, so there are no real metrics to track, but the call is here for an example

# %%
mmp.generatemetrics.Generate('data//02-06-13-31_0.1')
# Out:
# 2.0 pm 0.0 Average score over 1 games
# 17846.0 pm 0.0 Average score over 1 games

# %% [markdown]
# An example of metrics from a more substantial run can be seen here

# %%
mmp.generatemetrics.Generate('data//Smooth01')
# Out:
# 1.77 pm 1.45 Average score over 30 games
# 20684.43 pm 2798.56 Average score over 30 games
